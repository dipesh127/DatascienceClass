# %%
import pandas as pd
import numpy as np
import seaborn as sns
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
import pickle as pk
from sklearn.neighbors import KNeighborsClassifier

# %%
df=pd.read_csv(r"Downloads/winemag-data-130k-v2.csv")
df[["country","description"]]
# Out:
#          country                                        description
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
# [129971 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# id                           0
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64

# %%
text=df.description[0]
text
# Out:
# "Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity."

# %%
pip install wordcloud
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.1/174.1 kB 2.6 MB/s eta 0:00:00 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
obj=WordCloud().generate(text)

# %%
obj

# %%
plt.imshow(obj,interpolation="bilinear")
plt.show()

# %%
df1=pd.read_csv(r'cwurData.csv')

# %%
df1
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %%
text2=df1.institution[4]

# %%
text2
# Out:
# 'California Institute of Technology'

# %%
obj2=WordCloud().generate(text2)
plt.imshow(obj2,interpolation="bilinear")
plt.show()

# %%
a=np.array([12,232,23,44,55,666,33,44])

# %%
a.itemsize 
# used for finding the datatype size
# Out:
# 8

# %%
a.size
# Out:
# 8

# %%
a.shape
# Out:
# (8,)

# %%
c=a.reshape(2,2,2)

# %%
c.ndim
# Out:
# 3

# %%
# a.copy() vs a.view() copy is soft copy and view is deep copy

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
df2=pd.read_csv(r'CO2 Emissions_Canada.csv')

# %%
df2
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %%
df2.drop(["Make","Model","Vehicle Class","Transmission","Fuel Type","Fuel Consumption Hwy (L/100 km)","Fuel Consumption Comb (L/100 km)","Fuel Consumption Comb (mpg)"],axis=1)
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0                2.0          4                               9.9
# 1                2.4          4                              11.2
# 2                1.5          4                               6.0
# 3                3.5          6                              12.7
# 4                3.5          6                              12.1
# ...              ...        ...                               ...
# 7380             2.0          4                              10.7
# 7381             2.0          4                              11.2
# 7382             2.0          4                              11.7
# 7383             2.0          4                              11.2
# 7384             2.0          4                              12.2
#
#       CO2 Emissions(g/km)
# 0                     196
# 1                     221
# 2                     136
# 3                     255
# 4                     244
# ...

# %%
sns.lmplot(data=df2,x="Engine Size(L)",y="CO2 Emissions(g/km)",line_kws={'color':'green'})

# %%
x_bar=df2["Engine Size(L)"].mean()
y_bar=df2["CO2 Emissions(g/km)"].mean()
x_bar,y_bar
# Out:
# (3.160067704807041, 250.58469871360867)

# %%
df2["numerator"]=(df2["Engine Size(L)"]-x_bar)*(df2["CO2 Emissions(g/km)"]-y_bar)

# %%
df2
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %%
df2["denominator"]=(df2["Engine Size(L)"]-x_bar)**2
df2
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %%
theta1=df2['numerator'].sum()/df2['denominator'].sum()
theta1
# Out:
# 36.777315186419436

# %%
theta0=y_bar-(theta1*x_bar)
theta0
# Out:
# 134.36589272349508

# %%
plt.plot([1,2,3,4,5],[6,7,2,9,4])
plt.title("my Data")
plt.show()

# %%
df3=pd.read_csv(r'penguins.csv')
length=df3[['flipper_length_mm']]
mass=df3[['body_mass_g']]
plt.plot(length,mass)
plt.show()

# %%
names=['rahul','shyam','hari','jocker']
values=[212,222,333,424]
plt.bar(names,values)
plt.xlabel('names')
plt.ylabel('values')
plt.show()

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LinearRegression

# %%
realstateDf=pd.read_csv('sample_real_estate_data.csv')

# %%
realstateDf
# Out:
#            Area   City  Size (sq ft)  Price ($)
# 0   Countryside  CityD          3599     265838
# 1       Seaside  CityD           700     435674
# 2        Uptown  CityD          3604     979989
# 3       Seaside  CityE          2954     161087
# 4       Seaside  CityC          4145     693128
# 5        Suburb  CityA          1304     218451
# 6        Uptown  CityD          3231     547600
# 7        Uptown  CityB          3273     937437
# 8        Uptown  CityD          2070     539792
# 9       Seaside  CityB          3190     139353
# 10  Countryside  CityB          4340     293075
# 11       Uptown  CityD          1528     314283
# 12      Seaside  CityE          1002     414877
# 13       Suburb  CityB          4993     165318
# 14  Countryside  CityB          1370     865313
# 15       Suburb  CityD          4988     582690
# 16  Countryside  CityB           706     516880
# 17      Seaside  CityB          1984     691460
# 18     Downtown  CityD          1363     840976
# ...

# %%
x=realstateDf[['Size (sq ft)']]
y=realstateDf[['Price ($)']]
x,y
# Out:
# (    Size (sq ft)
#  0           3599
#  1            700
#  2           3604
#  3           2954
#  4           4145
#  5           1304
#  6           3231
#  7           3273
#  8           2070
#  9           3190
#  10          4340
#  11          1528
#  12          1002
#  13          4993
#  14          1370
#  15          4988
#  16           706
#  17          1984
#  18          1363
#  19          3290
#  20          1063
#  21          4691
#  22          2257
#  23          2178
#  24          3742
#  25          1559
#  26          2222
#  27          3814
#  28          3657
#  29          3125
#  30          3229
#  31          2097
#  32          3560
#  33          3193
#  34          4127
#  35          1863
#  36          2481
#  37          2163
#  38          2029
#  39          2538
#  40          3802
#  41          2737
#  42          1806
#  43          4529
#  44          3175
#  45          1782
#  46          1209
#  47          4913
#  48          4248
# ...

# %%
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[1559]])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[524057.9653327]])

# %%
df5=pd.read_csv(r'CO2 Emissions_Canada.csv')
df5
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %%
x=df5[['CO2 Emissions(g/km)']][0:150]
y=df5[['Cylinders']][0:150]

xaxis,yaxis
# Out:
# (     CO2 Emissions(g/km)
#  0                    196
#  1                    221
#  2                    136
#  3                    255
#  4                    244
#  ..                   ...
#  145                  250
#  146                  264
#  147                  264
#  148                  189
#  149                  228
#
#  [150 rows x 1 columns],
#       Cylinders
#  0            4
#  1            4
#  2            4
#  3            6
#  4            6
#  ..         ...
#  145          6
#  146          6
#  147          6
#  148          4
#  149          4
#
#  [150 rows x 1 columns])

# %% [markdown]
# model=LinearRegression()
# model.fit(x,y)

# %%
model.predict([[3]])
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 model.predict([[3]])
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_base.py:286, in LinearModel.predict(self, X)
#     272 def predict(self, X):
#     273     """
#     274     Predict using the linear model.
#     275
#    (...)
#     284         Returns predicted values.
#     285     """
# --> 286     return self._decision_function(X)
#
# File /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_base.py:267, in LinearModel._decision_function(self, X)
#     266 def _decision_function(self, X):
# --> 267     check_is_fitted(self)
#     269     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     270     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# ...

# %%
df6= pd.read_csv(r'Breast_Cancer.csv')

# %%
df6
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0      68  White        Married       T1      N1       IIA
# 1      50  White        Married       T2      N2      IIIA
# 2      58  White       Divorced       T3      N3      IIIC
# 3      58  White        Married       T1      N1       IIA
# 4      47  White        Married       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated     3  Regional           4        Positive
# 1     Moderately differentiated     2  Regional          35        Positive
# ...

# %%
df6.columns
# Out:
# Index(['Age', 'Race', 'Marital Status', 'T Stage ', 'N Stage', '6th Stage',
#        'differentiate', 'Grade', 'A Stage', 'Tumor Size', 'Estrogen Status',
#        'Progesterone Status', 'Regional Node Examined',
#        'Reginol Node Positive', 'Survival Months', 'Status'],
#       dtype='object')

# %%
df6.isnull()
# Out:
#         Age   Race  Marital Status  T Stage   N Stage  6th Stage  \
# 0     False  False           False     False    False      False
# 1     False  False           False     False    False      False
# 2     False  False           False     False    False      False
# 3     False  False           False     False    False      False
# 4     False  False           False     False    False      False
# ...     ...    ...             ...       ...      ...        ...
# 4019  False  False           False     False    False      False
# 4020  False  False           False     False    False      False
# 4021  False  False           False     False    False      False
# 4022  False  False           False     False    False      False
# 4023  False  False           False     False    False      False
#
#       differentiate  Grade  A Stage  Tumor Size  Estrogen Status  \
# 0             False  False    False       False            False
# ...

# %%
dataList=df6[['Age','Grade','Tumor Size','Regional Node Examined','Reginol Node Positive','Survival Months']]

# %%
dataList
# Out:
#       Age Grade  Tumor Size  Regional Node Examined  Reginol Node Positive  \
# 0      68     3           4                      24                      1
# 1      50     2          35                      14                      5
# 2      58     2          63                      14                      7
# 3      58     3          18                       2                      1
# 4      47     3          41                       3                      1
# ...   ...   ...         ...                     ...                    ...
# 4019   62     2           9                       1                      1
# 4020   56     2          46                      14                      8
# 4021   68     2          22                      11                      3
# 4022   58     2          44                      11                      1
# 4023   46     2          30                       7                      2
#
#       Survival Months
# 0                  60
# ...

# %%
df7=pd.read_csv(r'data.csv')

# %%
df7
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
dataList=df7[['radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean']]

# %%
dataList
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# [569 rows x 5 columns]

# %%
features=["radius_mean","texture_mean","perimeter_mean","area_mean","smoothness_mean"]
target="area_worst"

# %%
x=df7[features]
y=df7[target]
model=LinearRegression()
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)

# %%
df= pd.read_csv('Iris.csv')

# %%
x= df.drop(['Species'],axis=1)

# %%
y=df[['Species']]

# %%
y
# Out:
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model.fit(x_tain,y_train)

# %%
df= pd.read_csv('star_classification.csv')

# %%
df
# Out:
#              obj_ID       alpha      delta         u         g         r  \
# 0      1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501
# 1      1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2      1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3      1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4      1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
# ...             ...         ...        ...       ...       ...       ...
# 99995  1.237679e+18   39.620709  -2.594074  22.16759  22.97586  21.90404
# 99996  1.237679e+18   29.493819  19.798874  22.69118  22.38628  20.45003
# 99997  1.237668e+18  224.587407  15.700707  21.16916  19.26997  18.20428
# 99998  1.237661e+18  212.268621  46.660365  25.35039  21.63757  19.91386
# 99999  1.237661e+18  196.896053  49.464643  22.62171  21.79745  20.60115
#
#               i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# ...

# %%
x=df['cam_col'][:150]

# %%
y=df['alpha'][:150]

# %%
plt.scatter(x,y)
y=df['u'][:150]
plt.scatter(x,y)

# %%
df=pd.read_csv("heart_failure_clinical_records_dataset.csv")

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
x=df[["age","diabetes","high_blood_pressure","serum_creatinine"]]
y=df["platelets"]
model=LinearRegression()

# %%
# Out:
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
# Note: you may need to restart the kernel to use updated packages.
